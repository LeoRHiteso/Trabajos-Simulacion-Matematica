# %% [markdown]
# 15 De enero del 2024

# %% [markdown]
# # Presentación #

# %% [markdown]
# ## Quién soy yo? ##

# %% [markdown]
# Mi nombre es Leonardo Rodríguez Hernández,
#
# estudiante de ingeniería en Nanotecnología cursando el 8vo semestre
# Estoy un poco atrasado con las materias, pero bueno, no son carreras
# igual, falta mucho camino por empre

# %% [markdown]
# **Por qué nanotecnología?**

# %% [markdown]
# *Dicen que es la ciencia del futuro que otorgará infinitas posibilidades*

# %% [markdown]
# 1. Grandes oportunidades en el otro lado del mundo
# 2. Acceso a tecnologías más avanzadas
# 3. Un campo de estudio muy amplio
#
# * Ojo, también hay oportunidades aquí pero el camino puede ser más duro
# * Tampoco es tan barato

# %% [markdown]
# Un nanometro se mide como: $${nm = 1x10^{-9}}m $$ y es una unidad de interés por sus propiedades estructurales. La modificación de las propiedades estructurales se verán reflejadas en características físicas, químicas, etc.

# %% [markdown]
# ![image.png](attachment:86827c07-08b5-45cf-a5ec-f8abbd3bbef7.png)
